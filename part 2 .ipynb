# %%
pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.7.tar.gz (13 kB)
# Requirement already satisfied: Pillow in c:\users\misba\anaconda3\lib\site-packages (from pytesseract) (8.0.1)
# Building wheels for collected packages: pytesseract
#   Building wheel for pytesseract (setup.py): started
#   Building wheel for pytesseract (setup.py): finished with status 'done'
#   Created wheel for pytesseract: filename=pytesseract-0.3.7-py2.py3-none-any.whl size=13948 sha256=9a1ac459f521cff6a594169ac2a968e754acb475e5ba00fad0c826f06f46b049
#   Stored in directory: c:\users\misba\appdata\local\pip\cache\wheels\ac\5b\f4\d5bcc930771126a32285e058c576eda84e43691453a9f7ad71
# Successfully built pytesseract
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytesseract as tess
tess.pytesseract.tesseract_cmd=r'C:\Program Files\Tesseract-OCR\tesseract.exe'
from PIL import Image

img = Image.open('C:\\Users\\misba\\Desktop\\Dsample.jpg')
text = tess.image_to_string(img)

print(text)
# Out:
# ~ DISCHARGE SUMMARY
#
# NAME MASTER.ANKIT BISWASH ‘Age/Sex +3 Year(s) Male
# UHID APDI1.0000807307 1PNO + 208812
#
# Date of Admission: 22-Nov-2008 Date of Discharge :01-Apr-2009
# Room/Ward 4159 (Recommended-Govt Of Delhi)
#
#
#
# Banerji Unit NEUROSURGERY
# NEUROSURGEON
#
# 2, Dr.Varindera Paul Singh
# NEUROSURGEON
#
# DIAGNOSIS :
# Posterior Third Ventricle Ependymoma_
# Hydrocephalus
#
#
#
#
#
#
#
# Right side facial weakness - | month
# Headache & vomiting - 20 days
#
# Difficulty in walking & frequent falls - 15 days
#
# CECT head revealed posterior third ventricle tumor with hydrocephalus
#
#
#
#
#
# ON EXAMINATION
#
# Child - sick
#
# BP - 100/60 mm.
#
# Pupil - B/L 3 mm, reacting
# Fundus - B/L. mild papilloedema
# Moving all four limbs
